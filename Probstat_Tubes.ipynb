# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis, shapiro, kstest, t, norm, f
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown, display

# %%
df = pd.read_csv("anggur.csv")
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0             5.90            0.4451       0.1813        2.049401   0.070574  \
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %%
print(df.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
mean = df.mean()
mean
# Out:
# fixed acidity            7.152530
# volatile acidity         0.520839
# citric acid              0.270517
# residual sugar           2.567104
# chlorides                0.081195
# free sulfur dioxide     14.907679
# total sulfur dioxide    40.290150
# density                  0.995925
# pH                       3.303610
# sulphates                0.598390
# alcohol                 10.592280
# quality                  7.958000
# dtype: float64

# %% [markdown]
# Median

# %%
median = df.median()
median
# Out:
# fixed acidity            7.150000
# volatile acidity         0.524850
# citric acid              0.272200
# residual sugar           2.519430
# chlorides                0.082167
# free sulfur dioxide     14.860346
# total sulfur dioxide    40.190000
# density                  0.996000
# pH                       3.300000
# sulphates                0.595000
# alcohol                 10.610000
# quality                  8.000000
# dtype: float64

# %%
mode = df.mode().iloc[0]
mode
# Out:
# fixed acidity            6.540000
# volatile acidity         0.554600
# citric acid              0.301900
# residual sugar           0.032555
# chlorides                0.015122
# free sulfur dioxide      0.194679
# total sulfur dioxide    35.200000
# density                  0.995900
# pH                       3.340000
# sulphates                0.590000
# alcohol                  9.860000
# quality                  8.000000
# Name: 0, dtype: float64

# %%
std = df.std()
std
# Out:
# fixed acidity           1.201598
# volatile acidity        0.095848
# citric acid             0.049098
# residual sugar          0.987915
# chlorides               0.020111
# free sulfur dioxide     4.888100
# total sulfur dioxide    9.965767
# density                 0.002020
# pH                      0.104875
# sulphates               0.100819
# alcohol                 1.510706
# quality                 0.902802
# dtype: float64

# %%
var = df.var()
var
# Out:
# fixed acidity            1.443837
# volatile acidity         0.009187
# citric acid              0.002411
# residual sugar           0.975977
# chlorides                0.000404
# free sulfur dioxide     23.893519
# total sulfur dioxide    99.316519
# density                  0.000004
# pH                       0.010999
# sulphates                0.010164
# alcohol                  2.282233
# quality                  0.815051
# dtype: float64

# %%
minimum = df.min()
minimum
# Out:
# fixed acidity           3.320000
# volatile acidity        0.139900
# citric acid             0.116700
# residual sugar          0.032555
# chlorides               0.015122
# free sulfur dioxide     0.194679
# total sulfur dioxide    3.150000
# density                 0.988800
# pH                      2.970000
# sulphates               0.290000
# alcohol                 6.030000
# quality                 5.000000
# dtype: float64

# %%
maximum = df.max()
maximum
# Out:
# fixed acidity           11.490000
# volatile acidity         0.805100
# citric acid              0.409600
# residual sugar           5.550755
# chlorides                0.140758
# free sulfur dioxide     27.462525
# total sulfur dioxide    69.960000
# density                  1.002600
# pH                       3.710000
# sulphates                0.960000
# alcohol                 15.020000
# quality                 10.000000
# dtype: float64

# %%
q1 = df.quantile(0.25)
q1
# Out:
# fixed acidity            6.377500
# volatile acidity         0.456100
# citric acid              0.237800
# residual sugar           1.896330
# chlorides                0.066574
# free sulfur dioxide     11.426717
# total sulfur dioxide    33.785000
# density                  0.994600
# pH                       3.230000
# sulphates                0.530000
# alcohol                  9.560000
# quality                  7.000000
# Name: 0.25, dtype: float64

# %%
q2 = df.quantile(0.5)
q2
# Out:
# fixed acidity            7.150000
# volatile acidity         0.524850
# citric acid              0.272200
# residual sugar           2.519430
# chlorides                0.082167
# free sulfur dioxide     14.860346
# total sulfur dioxide    40.190000
# density                  0.996000
# pH                       3.300000
# sulphates                0.595000
# alcohol                 10.610000
# quality                  8.000000
# Name: 0.5, dtype: float64

# %%
q3 = df.quantile(0.75)
q3
# Out:
# fixed acidity            8.000000
# volatile acidity         0.585375
# citric acid              0.302325
# residual sugar           3.220873
# chlorides                0.095312
# free sulfur dioxide     18.313098
# total sulfur dioxide    47.022500
# density                  0.997200
# pH                       3.370000
# sulphates                0.670000
# alcohol                 11.622500
# quality                  9.000000
# Name: 0.75, dtype: float64

# %%
iqr = q3 - q1
iqr
# Out:
# fixed acidity            1.622500
# volatile acidity         0.129275
# citric acid              0.064525
# residual sugar           1.324544
# chlorides                0.028738
# free sulfur dioxide      6.886381
# total sulfur dioxide    13.237500
# density                  0.002600
# pH                       0.140000
# sulphates                0.140000
# alcohol                  2.062500
# quality                  2.000000
# dtype: float64

# %%
skewness = df.apply(lambda x: skew(x.dropna()))
skewness
# Out:
# fixed acidity          -0.028835
# volatile acidity       -0.197402
# citric acid            -0.045508
# residual sugar          0.132439
# chlorides              -0.051242
# free sulfur dioxide     0.007120
# total sulfur dioxide   -0.024024
# density                -0.076767
# pH                      0.147451
# sulphates               0.148975
# alcohol                -0.018963
# quality                -0.088920
# dtype: float64

# %%
kurt = df.apply(lambda x: kurtosis(x.dropna()))
kurt
# Out:
# fixed acidity          -0.025190
# volatile acidity        0.155051
# citric acid            -0.110151
# residual sugar         -0.048759
# chlorides              -0.251271
# free sulfur dioxide    -0.369135
# total sulfur dioxide    0.057636
# density                 0.010290
# pH                      0.074512
# sulphates               0.058502
# alcohol                -0.137068
# quality                 0.101756
# dtype: float64

# %%
df_summary = pd.DataFrame({'mean': mean, 'median': median, 'mode': mode, 'std': std, 'var': var, 'min': minimum, 'max': maximum, 'Q1': q1, 'Q2': q2, 'Q3': q3, 'IQR': iqr, 'skewness': skewness, 'kurtosis': kurt})

# %%
df_summary
# Out:
#                            mean     median       mode       std        var
# fixed acidity          7.152530   7.150000   6.540000  1.201598   1.443837  \
# volatile acidity       0.520839   0.524850   0.554600  0.095848   0.009187
# citric acid            0.270517   0.272200   0.301900  0.049098   0.002411
# residual sugar         2.567104   2.519430   0.032555  0.987915   0.975977
# chlorides              0.081195   0.082167   0.015122  0.020111   0.000404
# free sulfur dioxide   14.907679  14.860346   0.194679  4.888100  23.893519
# total sulfur dioxide  40.290150  40.190000  35.200000  9.965767  99.316519
# density                0.995925   0.996000   0.995900  0.002020   0.000004
# pH                     3.303610   3.300000   3.340000  0.104875   0.010999
# sulphates              0.598390   0.595000   0.590000  0.100819   0.010164
# alcohol               10.592280  10.610000   9.860000  1.510706   2.282233
# ...

# %%
for col in df.select_dtypes(include=[np.number]):
    fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
    sns.histplot(df[col], ax=axs[0], kde=True)
    sns.boxplot(df[col], ax=axs[1])
    fig.suptitle(f'Distribusi {col}', fontsize=14)
    plt.show()

# %%
# menentukan apakah setiap kolom numerik berdistribusi normal dengan menggunakan normality test Shapiro-Wilk dan Kolmogorov-Smirnov
for col in df.select_dtypes(include=[np.number]):
    print(f'Kolom {col}:')
    # normality test Shapiro-Wilk
    stat, p = shapiro(df[col])
    alpha = 0.05
    if p > alpha:
        print(f'    Shapiro-Wilk: p-value = {p:.4f}, distribusi normal (tidak ditolak H0)')
    else:
        print(f'    Shapiro-Wilk: p-value = {p:.4f}, distribusi tidak normal (ditolak H0)')
#     # normality test Kolmogorov-Smirnov
#     stat, p = kstest(df[col], 'norm')
#     if p > alpha:
#         print(f'    Kolmogorov-Smirnov: p-value = {p:.4f}, distribusi normal (tidak ditolak H0)')
#     else:
#         print(f'    Kolmogorov-Smirnov: p-value = {p:.4f}, distribusi tidak normal (ditolak H0)')
    # visualisasi histogram plot
    plt.figure(figsize=(5, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram {col}')
    plt.show()
# Out:
# Kolom fixed acidity:
#     Shapiro-Wilk: p-value = 0.8935, distribusi normal (tidak ditolak H0)
# Kolom volatile acidity:
#     Shapiro-Wilk: p-value = 0.0599, distribusi normal (tidak ditolak H0)
# Kolom citric acid:
#     Shapiro-Wilk: p-value = 0.2652, distribusi normal (tidak ditolak H0)
# Kolom residual sugar:
#     Shapiro-Wilk: p-value = 0.0449, distribusi tidak normal (ditolak H0)
# Kolom chlorides:
#     Shapiro-Wilk: p-value = 0.1747, distribusi normal (tidak ditolak H0)
# Kolom free sulfur dioxide:
#     Shapiro-Wilk: p-value = 0.0426, distribusi tidak normal (ditolak H0)
# Kolom total sulfur dioxide:
#     Shapiro-Wilk: p-value = 0.5367, distribusi normal (tidak ditolak H0)
# Kolom density:
#     Shapiro-Wilk: p-value = 0.8533, distribusi normal (tidak ditolak H0)
# Kolom pH:
#     Shapiro-Wilk: p-value = 0.1371, distribusi normal (tidak ditolak H0)
# Kolom sulphates:
#     Shapiro-Wilk: p-value = 0.1121, distribusi normal (tidak ditolak H0)
# Kolom alcohol:
# ...

# %% [markdown]
# # 4. Tes Hipotesis Satu Sampel

# %% [markdown]
# ### 4.a. Nilai rata-rata pH di atas 3.29

# %%
sns.boxplot(data=df, x="pH")
# Out:
# <Axes: xlabel='pH'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$H_0 = 3.29$$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$H_1 > 3.29$$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$\alpha = 0.05$$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %%
criVal = t.ppf(1-0.05, df["pH"].size-1)
criVal
# Out:
# 1.646380345427535

# %% [markdown]
# $$ t > 1.646 $$

# %% [markdown]
# akan dihitung $t_0$ seperti berikut
# $$
# t_0 = \frac{\bar{X}-\mu_0}{s/\sqrt{n}}
# $$

# %%
t0 = (np.mean(df["pH"]) - 3.29)/(np.std(df["pH"], ddof=1)/np.sqrt(df["pH"].size))
t0
# Out:
# 4.1037807933651145

# %% [markdown]
# akan dihitung nilai $p_{value}$

# %%
pVal = 1-t.cdf(t0,  df["pH"].size - 1)
pVal
# Out:
# 2.1979583063824748e-05

# %% [markdown]
# #### Langkah 5: Pengambilan Keputusan

# %% [markdown]
# Terima $H_0$ karena $t_0 < 1.646$ <br>
# Terima $H_0$ karena $p_{value} > 0.05$

# %% [markdown]
# ### 4.b. Nilai rata-rata Residual Sugar tidak sama dengan 2.50

# %%
sns.boxplot(data=df, x="residual sugar")
# Out:
# <Axes: xlabel='residual sugar'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$ H_0 = 2.50 $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$ H_1 \neq 2.50 $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %%
criVal = np.abs(t.ppf(0.05/2, df["residual sugar"].size-1))
criVal
# Out:
# 1.962341461133449

# %% [markdown]
# Oleh karena itu, daerah kritisnya adalah
# $$
# t > 1.962 \lor t < -1.962
# $$

# %% [markdown]
# akan dihitung $t_0$ seperti berikut
# $$
# t_0 = \frac{\bar{X}-\mu_0}{s/\sqrt{n}}
# $$

# %%
t0 = (np.mean(df["residual sugar"]) - 2.50)/(np.std(df["residual sugar"], ddof=1)/np.sqrt(df["residual sugar"].size))
t0
# Out:
# 2.1479619435539523

# %% [markdown]
# akan dihitung nilai $p_{value}$

# %%
pVal = (1-t.cdf(t0,  df["residual sugar"].size - 1))*2
pVal
# Out:
# 0.03195672670861671

# %% [markdown]
# #### Langkah 5: Pengambilan Keputusan

# %% [markdown]
# Tolak $H_0$ karena $ t_0 > 1.962 $ <br>
# Tolak $H_0$ karena $p_{value} < 0.05$

# %% [markdown]
# ### 4.c. Nilai rata-rata 150 baris pertama kolom sulphates bukan 0.65

# %%
sns.boxplot(data = df[:150], x = "sulphates")
# Out:
# <Axes: xlabel='sulphates'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$ H_0 = 0.65 $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$ H_1 \neq 2.50 $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %%
criVal = np.abs(t.ppf(0.05/2, df["sulphates"].size-1))
criVal
# Out:
# 1.962341461133449

# %% [markdown]
# Oleh karena itu, daerah kritisnya adalah
# $$
# t > 1.962 \lor t < -1.962
# $$

# %% [markdown]
# akan dihitung $t_0$ seperti berikut
# $$
# t_0 = \frac{\bar{X}-\mu_0}{s/\sqrt{n}}
# $$

# %%
t0 = (np.mean(df["sulphates"]) - 0.65)/(np.std(df["sulphates"], ddof=1)/np.sqrt(df["sulphates"].size))
t0
# Out:
# -16.18793452671077

# %% [markdown]
# akan dihitung nilai $p_{value}$

# %%
pVal = (1-t.cdf(t0,  df["sulphates"].size - 1))*2
pVal
# Out:
# 2.0

# %% [markdown]
# #### Langkah 5: Pengambilan Keputusan

# %% [markdown]
# Tolak $H_0$ karena $ t_0 < -1.962 $ <br>
# Tolak $H_0$ karena $p_{value} < 0.05$

# %% [markdown]
# ### 4.d. Nilai rata-rata total sulfur dioxide di bawah 35

# %%
sns.boxplot(data = df, x = "total sulfur dioxide")
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$ H_0 = 35 $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$ H_1 < 35 $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %%
criVal = np.abs(t.ppf(0.05/2, df["total sulfur dioxide"].size-1))
criVal
# Out:
# 1.962341461133449

# %% [markdown]
# Oleh karena itu, daerah kritisnya adalah
# $$
# t < -1.962
# $$

# %% [markdown]
# akan dihitung $t_0$ seperti berikut
# $$
# t_0 = \frac{\bar{X}-\mu_0}{s/\sqrt{n}}
# $$

# %%
t0 = (np.mean(df["total sulfur dioxide"]) - 0.65)/(np.std(df["total sulfur dioxide"], ddof=1)/np.sqrt(df["total sulfur dioxide"].size))
t0
# Out:
# 125.78375157527638

# %% [markdown]
# akan dihitung nilai $p_{value}$

# %%
pVal = (1-t.cdf(t0,  df["sulphates"].size - 1))
pVal
# Out:
# 0.0

# %% [markdown]
# #### Langkah 5: Pengambilan Keputusan

# %% [markdown]
# Terima $H_0$ karena $ t_0 > -1.962 $ <br>
# Terima $H_0$ karena $p_{value} < 0.05$

# %% [markdown]
# ### 4.e. Proporsi nilai total Sulfat Dioxide yang lebih dari 40, adalah tidak sama dengan 50%

# %%
sns.boxplot(data = df, x = "total sulfur dioxide")
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$ H_0 = 50% $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$ H_1 \neq 50% $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$ dan Daerah Kritis

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %%
criVal = np.abs(t.ppf(0.05/2, df["total sulfur dioxide"].size-1))
criVal
# Out:
# 1.962341461133449

# %% [markdown]
# Oleh karena itu, daerah kritisnya adalah
# $$
# z > 1.962 \lor z < -1.962
# $$

# %% [markdown]
# akan dihitung $\mu$ dan $\sigma$ seperti berikut
# $$
# \mu = np
# $$
# $$
# \sigma = \sqrt{npq}
# $$

# %%
mu = df["total sulfur dioxide"].shape[0] * 0.1
mu
# Out:
# 100.0

# %%
sigma = np.sqrt(df["total sulfur dioxide"].shape[0]*0.1*0.9)
sigma
# Out:
# 9.486832980505138

# %% [markdown]
# Menghitung jumlah data yang > 40

# %%
tsd40 = df[df["total sulfur dioxide"] > 40]["total sulfur dioxide"].size
tsd40
# Out:
# 512

# %%
z = (tsd40 - mu)/sigma
z
# Out:
# 43.428613199645746

# %%
p = (1 - norm.cdf(z)) * 2
p
# Out:
# 0.0

# %% [markdown]
# #### Langkah 5: Pengambilan Keputusan

# %% [markdown]
# Tolak $H_0$ karena $ z > 1.962 $ <br>
# Tolak $H_0$ karena $p_{value} < 0.05$

# %% [markdown]
# # 5. Tes Hipotesis Dua Sampel

# %% [markdown]
# ### 5.a. Data kolom fixed acidity dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama

# %%
dataAwal = df["fixed acidity"].iloc[:df["fixed acidity"].size//2]
dataAkhir = df["fixed acidity"].iloc[df["fixed acidity"].size//2:]

# %%
sns.boxplot(x = dataAwal)
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
sns.boxplot(x = dataAkhir)
# Out:
# <Axes: xlabel='fixed acidity'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$
# H_0: \mu_{awal} - \mu_{akhir} = 0
# $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$
# H_1: \mu_{awal} - \mu_{akhir} \neq 0
# $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %% [markdown]
# $$
# z = \frac{(\bar{x}_1 - \bar{x}_2) - (\mu_{1}-\mu_{2})}{\sqrt{\sigma_1^2/n_1 + \sigma_2^2/n_2}}
# $$

# %% [markdown]
# Daerah kritisnya adalah
# $$ z<-z_{\alpha/2} \lor z>z_{\alpha/2} $$

# %% [markdown]
# #### Langkah 5: Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.

# %%
x1bar = dataAwal.mean()
x2bar = dataAkhir.mean()
sigma1 = dataAwal.std()
sigma2 = dataAkhir.std()
n1 = dataAwal.count()
n2 = dataAkhir.count()

z = ((x1bar-x2bar)-0)/np.sqrt(sigma1**2/n1+sigma2**2/n2)

pVal = 2*(1-norm.cdf(z))

zaper2 = norm.ppf(1-0.05/2)
print(f"z = {z}")
print(f"p = {pVal}")
print(f"z_a/2 = {zaper2}")
# Out:
# z = 0.02604106999906379
# p = 0.9792245804254096
# z_a/2 = 1.959963984540054

# %% [markdown]
# #### Langkah 6: Pengambilan Keputusan

# %% [markdown]
# $H_0$ tidak ditolak karena $ |z| < 1.9599 $ <br>
# $H_0$ tidak ditolak semakin kuat karena $p_{value} \ge 0.05$

# %% [markdown]
# ### 5.b. Data kolom chlorides dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar daripada bagian akhir sebesar 0.001

# %%
dataAwal = df["chlorides"].iloc[:df["chlorides"].size//2]
dataAkhir = df["chlorides"].iloc[df["chlorides"].size//2:]

# %%
sns.boxplot(x = dataAwal)
# Out:
# <Axes: xlabel='chlorides'>

# %%
sns.boxplot(x = dataAkhir)
# Out:
# <Axes: xlabel='chlorides'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$
# H_0: \mu_{awal} - \mu_{akhir} = 0.001
# $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$
# H_1: \mu_{awal} - \mu_{akhir} \neq 0.001
# $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %% [markdown]
# $$
# z = \frac{(\bar{x}_1 - \bar{x}_2) - (\mu_{1}-\mu_{2})}{\sqrt{\sigma_1^2/n_1 + \sigma_2^2/n_2}}
# $$

# %% [markdown]
# Daerah kritisnya adalah
# $$ z<-z_{\alpha/2} \lor z>z_{\alpha/2} $$

# %% [markdown]
# #### Langkah 5: Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.

# %%
x1bar = dataAwal.mean()
x2bar = dataAkhir.mean()
sigma1 = dataAwal.std()
sigma2 = dataAkhir.std()
n1 = dataAwal.count()
n2 = dataAkhir.count()

z = ((x1bar-x2bar)-0.001)/np.sqrt(sigma1**2/n1+sigma2**2/n2)

pVal = 2*(1-norm.cdf(abs(z)))

zaper2 = norm.ppf(1-0.05/2)
print(f"z = {z}")
print(f"p = {pVal}")
print(f"z_a/2 = {zaper2}")
# Out:
# z = -0.4673171228521319
# p = 0.640273007581107
# z_a/2 = 1.959963984540054

# %% [markdown]
# #### Langkah 6: Pengambilan Keputusan

# %% [markdown]
# $H_0$ tidak ditolak karena $ |z| < 1.9599 $ <br>
# $H_0$ tidak ditolak semakin kuat karena $p_{value} \ge 0.05$

# %% [markdown]
# ### 5.c. Benarkah rata-rata sampel 25 baris pertama kolom Volatile Acidity sama dengan rata-rata 25 baris pertama kolom Sulphates

# %%
dataAwal = df["volatile acidity"][:25]
dataAkhir = df["sulphates"][:25]

# %%
sns.boxplot(x = dataAwal)
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.boxplot(x = dataAkhir)
# Out:
# <Axes: xlabel='sulphates'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$
# H_0: \mu_{awal} - \mu_{akhir} = 0
# $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$
# H_1: \mu_{awal} - \mu_{akhir} \neq 0
# $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %% [markdown]
# $$
# z = \frac{(\bar{x}_1 - \bar{x}_2) - (\mu_{1}-\mu_{2})}{\sqrt{\sigma_1^2/n_1 + \sigma_2^2/n_2}}
# $$

# %% [markdown]
# Daerah kritisnya adalah
# $$ z<-z_{\alpha/2} \lor z>z_{\alpha/2} $$

# %% [markdown]
# #### Langkah 5: Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.

# %%
x1bar = dataAwal.mean()
x2bar = dataAkhir.mean()
sigma1 = dataAwal.std()
sigma2 = dataAkhir.std()
n1 = dataAwal.count()
n2 = dataAkhir.count()

z = ((x1bar-x2bar)-0.001)/np.sqrt(sigma1**2/n1+sigma2**2/n2)

pVal = 2*(1-norm.cdf(abs(z)))

zaper2 = norm.ppf(1-0.05/2)
print(f"z = {z}")
print(f"p = {pVal}")
print(f"z_a/2 = {zaper2}")
# Out:
# z = -2.6724731749938426
# p = 0.007529439418405115
# z_a/2 = 1.959963984540054

# %% [markdown]
# #### Langkah 6: Pengambilan Keputusan

# %% [markdown]
# $H_0$ ditolak karena $ |z| > 1.9599 $ <br>
# $H_0$ ditolak semakin kuat karena $p_{value} < 0.05$

# %% [markdown]
# ### 5.d. Bagian awal kolom residual sugar memiliki variansi yang sama dengan bagian akhirnya

# %%
dataAwal = df["residual sugar"].iloc[:df["residual sugar"].size//2]
dataAkhir = df["residual sugar"].iloc[df["residual sugar"].size//2:]

# %%
sns.boxplot(x = dataAwal)
# Out:
# <Axes: xlabel='residual sugar'>

# %%
sns.boxplot(x = dataAkhir)
# Out:
# <Axes: xlabel='residual sugar'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$
# H_0: \sigma_{awal}^2 = \sigma_{akhir}^2
# $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$
# H_1: \sigma_{awal}^2 \neq \sigma_{akhir}^2
# $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %% [markdown]
# $$
# f = s_1^2/s_2^2
# $$

# %% [markdown]
# Daerah kritisnya adalah
# $$ f>f_{1-\alpha/2}(v_1,v_2) \lor f<f_{\alpha/2}(v_1,v_2) $$

# %% [markdown]
# #### Langkah 5: Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.

# %%
s1 = dataAwal.var()
s2 = dataAkhir.var()
d1 = dataAwal.count()-1
d2 = dataAkhir.count()-1

fVal = s1/s2

pVal = (f.sf(fVal,d1,d2))

f_aper2 = f.ppf(0.05/2,d1,d2)
f_1min = f.ppf(1-0.05/2,d1,d2)
print(f"f = {fVal}")
print(f"p = {pVal}")
print(f"f_a/2 = {f_aper2}")
print(f"f_1-a/2 = {f_1min}")
# Out:
# f = 0.9420041066941615
# p = 0.7475898202376912
# f_a/2 = 0.8388857772763105
# f_1-a/2 = 1.1920574017201653

# %% [markdown]
# #### Langkah 6: Pengambilan Keputusan

# %% [markdown]
# $H_0$ tidak ditolak karena $ 0.838 < f < 1.19 $ <br>
# $H_0$ tidak ditolak semakin kuat karena $p_{value} < 0.05$

# %% [markdown]
# ### 5.e. Proporsi nilai setengah bagian awal alcohol yang lebih dari 7, adalah lebih besar daripada, proporsi nilai yang sama di setengah bagian akhir alcoho

# %%
dataAwal = df["alcohol"].iloc[:df["alcohol"].size//2]
dataAkhir = df["alcohol"].iloc[df["alcohol"].size//2:]

# %%
sns.boxplot(x = dataAwal)
# Out:
# <Axes: xlabel='alcohol'>

# %%
sns.boxplot(x = dataAkhir)
# Out:
# <Axes: xlabel='alcohol'>

# %% [markdown]
# #### Langkah 1: Penentuan $H_0$

# %% [markdown]
# $$
# H_0: p_{awal} - p_{akhir} = 0
# $$

# %% [markdown]
# #### Langkah 2: Penentuan $H_1$

# %% [markdown]
# $$
# H_1: p_{awal} - p_{akhir} > 0
# $$

# %% [markdown]
# #### Langkah 3: Penentuan $\alpha$

# %% [markdown]
# $$ \alpha = 0.05 $$

# %% [markdown]
# #### Langkah 4: Pengujian Statistik dan Daerah Kritis

# %% [markdown]
# $$
# z = \frac{\hat{p}_1 - \hat{p}_2}{\sqrt{\hat{p}\hat{q}(1/n_1+1/n_2)}}
# $$

# %% [markdown]
# Daerah kritisnya adalah
# $$ z>z_\alpha $$

# %% [markdown]
# #### Langkah 5: Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.

# %%
x1 = dataAwal[dataAwal>7].count()
x2 = dataAkhir[dataAkhir>7].count()
n1 = dataAwal.count()
n2 = dataAkhir.count()

p = (x1+x2)/(n1+n2)
q = 1-p

p1 = x1/n1
p2 = x2/n2

z = (p1 - p2)/(np.sqrt(p*q*(1/n1+1/n2)))

pVal = 1-norm.cdf(z)

z_a = abs(norm.ppf(0.05))
print(f"z = {z}")
print(f"p = {pVal}")
print(f"z_a = {z_a}")
# Out:
# z = 0.0
# p = 0.5
# z_a = 1.6448536269514729

# %% [markdown]
# #### Langkah 6: Pengambilan Keputusan

# %% [markdown]
# $H_0$ tidak ditolak karena $ z < 1.644 $
